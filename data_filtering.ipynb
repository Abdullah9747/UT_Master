# %%
from __init__ import DataFilter
DF = DataFilter()

# %%
PREDEFINED_TYPES = ['int', 'double', 'float', 'long', 'short', 'byte', 'boolean', 'char']
input_file = './Dataset'
output_file = './output/ExtractedData.csv'

DF.process_and_filter_files(input_file, output_file, PREDEFINED_TYPES)

# %%
input_file = './output/ExtractedData.csv'
output_file = './output/FilteredData.csv'
DF.check_functionIsBuildable(input_file, output_file)

# %%
input_file = './output/ExtractedData.csv'
output_file = './output/testing_output.csv'
DataFilter.check_java_function_compatibility(input_file, output_file)

# %%
DF = DataFilter()
Percentage = 0.1249
input_file = './output/testing_output.csv'
output_file = './output/SelectedData.csv'
DF.select_random_data(input_file, output_file, Percentage)
# Out:
# Selected 2414 rows from ./output/testing_output.csv
# Fair selection completed! Selected data saved to ./output/SelectedData.csv
